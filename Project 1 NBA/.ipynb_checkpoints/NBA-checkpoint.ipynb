# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np

# %%
# Study data files
nba1 = "data/General_1_50.csv"
nba2 = "data/General_51_100.csv" 
nba3 = "data/General_101_150.csv"
nba4 = "data/General_151_200.csv"

# %%
# Read the mouse data and the study results
nba01 = pd.read_csv(nba1)
nba02 = pd.read_csv(nba2)
nba03 = pd.read_csv(nba3)
nba04 = pd.read_csv(nba4)

# %%
# Combine the data into a single dataset
frames = [nba01,nba02,nba03,nba04]
merged_data_df = pd.concat(frames)

# %%
# Display the data table for preview
merged_data_df.head(100)
# Out:
#      ID                   PLAYER TEAM  AGE  GP   W   L   MIN   PTS   FGM  ...  \
# 0     1              Joel Embiid  PHI   29  66  43  23  34.6  33.1  11.0  ...
# 1     2              Luka Doncic  DAL   24  66  33  33  36.2  32.4  10.9  ...
# 2     3           Damian Lillard  POR   32  58  27  31  36.3  32.2   9.6  ...
# 3     4  Shai Gilgeous-Alexander  OKC   24  68  33  35  35.5  31.4  10.4  ...
# 4     5    Giannis Antetokounmpo  MIL   28  63  47  16  32.1  31.1  11.2  ...
# ..  ...                      ...  ...  ...  ..  ..  ..   ...   ...   ...  ...
# 45   96          Harrison Barnes  SAC   30  82  48  34  32.5  15.0   4.6  ...
# 46   97        Immanuel Quickley  NYK   23  81  47  34  28.9  14.9   5.2  ...
# 47   98          Malcolm Brogdon  BOS   30  67  46  21  26.0  14.9   5.3  ...
# 48   99           Alperen Sengun  HOU   20  75  18  57  28.9  14.8   5.9  ...
# 49  100            Tobias Harris  PHI   30  74  47  27  32.9  14.7   5.7  ...
#
# ...
